# %%
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
jpgfile = Image.open("input/train_img/train_1a.png")
plt.imshow(jpgfile)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-3d7c2c633cd3> in <module>()
# ----> 1 jpgfile.resize(32,32)
#
# /usr/lib/python3/dist-packages/PIL/Image.py in resize(self, size, resample)
#    1537                 NEAREST, BILINEAR, BICUBIC, LANCZOS, BOX, HAMMING,
#    1538         ):
# -> 1539             raise ValueError("unknown resampling filter")
#    1540
#    1541         self.load()
#
# ValueError: unknown resampling filter
